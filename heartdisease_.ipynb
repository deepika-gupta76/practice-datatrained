# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
ds=pd.read_csv('heartdisease.csv')
ds
# Out:
#      63  1  4  140  260  0  1.1  112 1.2     3  2  ? ?.1  2.1
# 0    44  1  4  130  209  0    1  127   0     0  ?  ?   ?    0
# 1    60  1  4  132  218  0    1  140   1   1.5  3  ?   ?    2
# 2    55  1  4  142  228  0    1  149   1   2.5  1  ?   ?    1
# 3    66  1  3  110  213  1    2   99   1   1.3  2  ?   ?    0
# 4    66  1  3  120    0  0    1  120   0  -0.5  1  ?   ?    0
# ..   .. .. ..  ...  ... ..  ...  ...  ..   ... .. ..  ..  ...
# 194  54  0  4  127  333  1    1  154   0     0  ?  ?   ?    1
# 195  62  1  1    ?  139  0    1    ?   ?     ?  ?  ?   ?    0
# 196  55  1  4  122  223  1    1  100   0     0  ?  ?   6    2
# 197  58  1  4    ?  385  1    2    ?   ?     ?  ?  ?   ?    0
# 198  62  1  2  120  254  0    2   93   1     0  ?  ?   ?    1
#
# [199 rows x 14 columns]

# %%
df=pd.DataFrame(data=ds)
df
# Out:
#      63  1  4  140  260  0  1.1  112 1.2     3  2  ? ?.1  2.1
# 0    44  1  4  130  209  0    1  127   0     0  ?  ?   ?    0
# 1    60  1  4  132  218  0    1  140   1   1.5  3  ?   ?    2
# 2    55  1  4  142  228  0    1  149   1   2.5  1  ?   ?    1
# 3    66  1  3  110  213  1    2   99   1   1.3  2  ?   ?    0
# 4    66  1  3  120    0  0    1  120   0  -0.5  1  ?   ?    0
# ..   .. .. ..  ...  ... ..  ...  ...  ..   ... .. ..  ..  ...
# 194  54  0  4  127  333  1    1  154   0     0  ?  ?   ?    1
# 195  62  1  1    ?  139  0    1    ?   ?     ?  ?  ?   ?    0
# 196  55  1  4  122  223  1    1  100   0     0  ?  ?   6    2
# 197  58  1  4    ?  385  1    2    ?   ?     ?  ?  ?   ?    0
# 198  62  1  2  120  254  0    2   93   1     0  ?  ?   ?    1
#
# [199 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['63', '1', '4', '140', '260', '0', '1.1', '112', '1.2', '3', '2', '?',
#        '?.1', '2.1'],
#       dtype='object')

# %% [markdown]
# Only 14 attributes used:
# 1. #3 (age)
# 2. #4 (sex)
# 3. #9 (cp)
# 4. #10 (trestbps)
# 5. #12 (chol)
# 6. #16 (fbs)
# 7. #19 (restecg)
# 8. #32 (thalach)
# 9. #38 (exang)
# 10. #40 (oldpeak)
# 11. #41 (slope)
# 12. #44 (ca)
# 13. #51 (thal)
# 14. #58 (num) (the predicted attribute)
#
# not able to understand please explain how index column is different to attributes

# %%
df.dtypes
# Out:
# 63      int64
# 1       int64
# 4       int64
# 140    object
# 260    object
# 0      object
# 1.1     int64
# 112    object
# 1.2    object
# 3      object
# 2      object
# ?      object
# ?.1    object
# 2.1     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   63      199 non-null    int64
#  1   1       199 non-null    int64
#  2   4       199 non-null    int64
#  3   140     199 non-null    object
#  4   260     199 non-null    object
#  5   0       199 non-null    object
#  6   1.1     199 non-null    int64
#  7   112     199 non-null    object
#  8   1.2     199 non-null    object
#  9   3       199 non-null    object
#  10  2       199 non-null    object
#  11  ?       199 non-null    object
#  12  ?.1     199 non-null    object
#  13  2.1     199 non-null    int64
# dtypes: int64(5), object(9)
# memory usage: 14.8+ KB

# %%
df.isnull().sum()
# Out:
# 63     0
# 1      0
# 4      0
# 140    0
# 260    0
# 0      0
# 1.1    0
# 112    0
# 1.2    0
# 3      0
# 2      0
# ?      0
# ?.1    0
# 2.1    0
# dtype: int64

# %%
df.describe()
# Out:
#                63           1           4         1.1         2.1
# count  199.000000  199.000000  199.000000  199.000000  199.000000
# mean    59.331658    0.969849    3.502513    0.733668    1.517588
# std      7.827080    0.171433    0.796928    0.684918    1.222038
# min     35.000000    0.000000    1.000000    0.000000    0.000000
# 25%     55.000000    1.000000    3.000000    0.000000    0.000000
# 50%     60.000000    1.000000    4.000000    1.000000    1.000000
# 75%     64.000000    1.000000    4.000000    1.000000    3.000000
# max     77.000000    1.000000    4.000000    2.000000    4.000000

# %%
df_cor=df.corr()
df_cor
# Out:
#            63         1         4       1.1       2.1
# 63   1.000000  0.033837 -0.039809  0.001487  0.286630
# 1    0.033837  1.000000  0.037525  0.060305  0.147190
# 4   -0.039809  0.037525  1.000000  0.033617  0.167202
# 1.1  0.001487  0.060305  0.033617  1.000000 -0.033597
# 2.1  0.286630  0.147190  0.167202 -0.033597  1.000000

# %%
plt.figure
sns.heatmap(df_cor)

# %% [markdown]
# not able to understand column details properly

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0A25EB98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0A28D5C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0A2A1FB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0A2C39B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0A2E33D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0A2F7DD8>]],
#       dtype=object)
